# %% [markdown]
# # ANN - Artificial Neural Network

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn import metrics 
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.utils import to_categorical

# %% [markdown]
# ## MFCC

# %%
mfcc_df = pd.read_csv('../../../Data/Features/MFCC_Data.csv',index_col=0)

# %%
mfcc_df.head()
# Out:
#        MFCC_1      MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6  \
# 12 -289.21213  110.805435 -21.313496  15.978510 -22.054483   3.363043
# 27 -257.24110   99.345795 -10.082610  29.844202  -9.154385   3.967014
# 29 -162.67676   97.780200 -46.044758  14.602550 -16.414543   1.585601
# 30 -440.63580  130.743640   0.374263  29.192797  -6.186107  13.845780
# 31 -454.82550  133.810840  -1.461820  33.532536 -11.242642  18.659878
#
#        MFCC_7     MFCC_8     MFCC_9    MFCC_10  ...   MFCC_42   MFCC_43  \
# 12 -11.504783   4.508069  -4.662264   4.716395  ...  0.059355  2.855525
# 27 -12.355303  -1.142314 -10.105771  -5.000117  ...  0.989184  0.651739
# 29 -16.828533  -6.045789  -7.403815   2.705874  ...  0.827159 -0.507063
# 30 -11.397534   9.895559  -3.589840   6.202628  ... -0.201709  2.073562
# 31 -11.550693  15.192266  -6.038576  10.610360  ... -0.389133  1.939244
#
#      MFCC_44   MFCC_45   MFCC_46   MFCC_47   MFCC_48   MFCC_49   MFCC_50  \
# 12  1.902572 -0.555519  1.149774  2.588985  1.999745 -1.386203 -1.444516
# 27  0.792287  1.076015 -0.238661  1.113345  1.410870  0.780703  1.017746
# 29  0.961427  0.716429 -0.255313  0.953160  0.523185 -0.263831  0.031629
# 30  0.830128 -0.185219 -0.298924  1.384827 -0.419494  0.965666 -0.594039
# 31  0.504643  0.578664 -0.076486  1.395140 -0.559993 -0.541744 -1.073842
#
#     Label
# 12    ang
# 27    ang
# 29    ang
# 30    sad
# 31    sad
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Number of labels

# %%
new_lab = mfcc_df['Label']
count_lab= len(mfcc_df['Label'].value_counts())
count_lab
# Out:
# 3

# %% [markdown]
# ### Extract features and labels and store it in variables for further model training

# %%
features = mfcc_df.drop(['Label'], axis=1).values
lab = mfcc_df['Label'].values

# Convert features and corresponding classification labels into numpy arrays
X = np.array(features.tolist())
y = np.array(lab.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# %% [markdown]
# ### Split the data into training and testing set

# %%
# split the dataset 
x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.25, random_state = 4)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2421, 50)
# (2421, 3)
# (807, 50)
# (807, 3)

# %% [markdown]
# ### Build Model

# %%
mfcc_ann_model = Sequential()
mfcc_ann_model.add(Dense(64, input_dim=50, activation='relu'))
mfcc_ann_model.add(Dense(count_lab, activation='softmax'))

# %% [markdown]
# ### MFCC ANN Model Summary

# %%
mfcc_ann_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                3264
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 3,459
# Trainable params: 3,459
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile & Fit Model

# %%
mfcc_ann_model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
num_epochs = 50
num_batch_size = 128

mfcc_ann_his = mfcc_ann_model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 2s
50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6336 - accuracy: 0.7212 - val_loss: 0.7270 - val_accuracy: 0.6914
# Epoch 30/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6223 - accuracy: 0.7311 - val_loss: 0.7131 - val_accuracy: 0.7038
# Epoch 31/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6174 - accuracy: 0.7356 - val_loss: 0.7135 - val_accuracy: 0.7175
# Epoch 32/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6287 - accuracy: 0.7187 - val_loss: 0.7204 - val_accuracy: 0.7051
# Epoch 33/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6129 - accuracy: 0.7319 - val_loss: 0.7108 - val_accuracy: 0.7076
# Epoch 34/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6276 - accuracy: 0.7204 - val_loss: 0.8091 - val_accuracy: 0.6642
# Epoch 35/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6412 - accuracy: 0.7257 - val_loss: 0.7165 - val_accuracy: 0.7038
# Epoch 36/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6204 - accuracy: 0.7191 - val_loss: 0.7367 - val_accuracy: 0.6964
# Epoch 37/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6553 - accuracy: 0.7129 - val_loss: 0.7875 - val_accuracy: 0.6691
# Epoch 38/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6209 - accuracy: 0.7336 - val_loss: 0.7248 - val_accuracy: 0.6964
# Epoch 39/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6205 - accuracy: 0.7311 - val_loss: 0.7164 - val_accuracy: 0.7125
# Epoch 40/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6230 - accuracy: 0.7245 - val_loss: 0.7205 - val_accuracy: 0.7001
# Epoch 41/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5794 - accuracy: 0.7443 - val_loss: 0.7161 - val_accuracy: 0.7125
# Epoch 42/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5849 - accuracy: 0.7423 - val_loss: 0.7424 - val_accuracy: 0.6902
# Epoch 43/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5956 - accuracy: 0.7406 - val_loss: 0.7195 - val_accuracy: 0.7014
# Epoch 44/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6061 - accuracy: 0.7390 - val_loss: 0.7658 - val_accuracy: 0.6778
# Epoch 45/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6049 - accuracy: 0.7315 - val_loss: 0.8507 - val_accuracy: 0.6357
# Epoch 46/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6491 - accuracy: 0.7154 - val_loss: 0.7282 - val_accuracy: 0.7113
# Epoch 47/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6039 - accuracy: 0.7381 - val_loss: 0.7241 - val_accuracy: 0.7113
# Epoch 48/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5977 - accuracy: 0.7369 - val_loss: 0.8570 - val_accuracy: 0.6642
# Epoch 49/50
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6047 - accuracy: 0.7295 - val_loss: 0.7356 - val_accuracy: 0.7187
# Epoch 50/50
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5662 - accuracy: 0.7551 - val_loss: 0.7130 - val_accuracy: 0.7138

# %% [markdown]
# ### Evaluating the model on the training and testing set

# %%
# Evaluating the model on the training and testing set
mfccscore = mfcc_ann_model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: {0:.2%}".format(mfccscore[1]))

mfccscore = mfcc_ann_model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: {0:.2%}".format(mfccscore[1]))
# Out:
# Training Accuracy: 76.87%
# Testing Accuracy: 71.38%

# %% [markdown]
# ### Plot Epochs for Accracy and Loss

# %%
plt.plot(mfcc_ann_his.history['accuracy'])
plt.plot(mfcc_ann_his.history['val_accuracy'])
plt.title('MFCC ANN Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(mfcc_ann_his.history['loss'])
plt.plot(mfcc_ann_his.history['val_loss'])
plt.title('MFCC ANN Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### PCP Feature

# %%
pcp_df = pd.read_csv('../../../Data/Features/PCP_Data.csv',index_col=0)

# %%
pcp_df.head()
# Out:
#         PCP1      PCP2      PCP3      PCP4      PCP5      PCP6      PCP7  \
# 12  0.468665  0.418584  0.470229  0.402123  0.438475  0.465702  0.430603
# 27  0.463213  0.431536  0.431190  0.410230  0.384602  0.391240  0.444501
# 29  0.393176  0.394829  0.384227  0.407025  0.433312  0.394724  0.341926
# 30  0.546842  0.518859  0.569832  0.522063  0.484166  0.571499  0.470337
# 31  0.690118  0.551490  0.515464  0.597981  0.554355  0.688720  0.588746
#
#         PCP8      PCP9     PCP10     PCP11     PCP12 Label
# 12  0.472777  0.384107  0.399642  0.339348  0.520844   ang
# 27  0.380445  0.379131  0.423372  0.379215  0.408315   ang
# 29  0.305187  0.309041  0.324220  0.306156  0.315559   ang
# 30  0.477768  0.473719  0.458764  0.482684  0.630568   sad
# 31  0.407920  0.408882  0.432478  0.442955  0.572069   sad

# %% [markdown]
# ### Extract features and Labels

# %%
pcpf = pcp_df.drop(['Label'], axis=1).values
pcp_lab = pcp_df['Label'].values
count= len(pcp_lab)

# %% [markdown]
# ### Convert features and corresponding classification labels into numpy arrays

# %%
X_pcp = np.array(pcpf.tolist())
y_pcp = np.array(pcp_lab.tolist())

# %% [markdown]
# ### Encode the classification labels

# %%
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(y_pcp)
encoded_labels = to_categorical(encoded_labels)

# %% [markdown]
# ### Split dataset into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pcp, encoded_labels, test_size=0.2, random_state=21)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2421, 50)
# (2582, 3)
# (807, 50)
# (646, 3)

# %% [markdown]
# ### Build Model

# %%
pcp_ann_model = Sequential()
pcp_ann_model.add(Dense(256, activation='relu', input_shape=(12,)))
pcp_ann_model.add(Dropout(0.3))
pcp_ann_model.add(Dense(128, activation='relu'))
pcp_ann_model.add(Dropout(0.3))
pcp_ann_model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ### MFCC ANN Model Summary

# %%
pcp_ann_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 256)               3328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 36,611
# Trainable params: 36,611
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile and Fit the model

# %%
pcp_ann_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
pcp_his=pcp_ann_model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# 81/81 [==============================] - 1s 6ms/step - loss: 0.8629 - accuracy: 0.5759 - val_loss: 0.8482 - val_accuracy: 0.5913
# Epoch 2/50
# 81/81 [==============================] - 1s 7ms/step - loss: 0.8630 - accuracy: 0.5724 - val_loss: 0.8593 - val_accuracy: 0.5882
# Epoch 3/50
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8645 - accuracy: 0.5744 - val_loss: 0.8409 - val_accuracy: 0.5929
# Epoch 4/50
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8688 - accuracy: 0.5817 - val_loss: 0.8348 - val_accuracy: 0.5898
# Epoch 5/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8591 - accuracy: 0.5724 - val_loss: 0.8445 - val_accuracy: 0.5820
# Epoch 6/50
# 81/81 [==============================] - 1s 6ms/step - loss: 0.8615 - accuracy: 0.5697 - val_loss: 0.8421 - val_accuracy: 0.5882
# Epoch 7/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8628 - accuracy: 0.5751 - val_loss: 0.8436 - val_accuracy: 0.5851
# Epoch 8/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8615 - accuracy: 0.5887 - val_loss: 0.8367 - val_accuracy: 0.6006
# Epoch 9/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8665 - accuracy: 0.5720 - val_loss: 0.8366 - val_accuracy: 0.5913
# Epoch 10/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8620 - accuracy: 0.5720 - val_loss: 0.8371 - val_accuracy: 0.5944
# Epoch 11/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.
50
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8531 - accuracy: 0.5732 - val_loss: 0.8458 - val_accuracy: 0.5836
# Epoch 42/50
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8568 - accuracy: 0.5837 - val_loss: 0.8456 - val_accuracy: 0.5882
# Epoch 43/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8557 - accuracy: 0.5871 - val_loss: 0.8405 - val_accuracy: 0.5929
# Epoch 44/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8556 - accuracy: 0.5705 - val_loss: 0.8359 - val_accuracy: 0.5898
# Epoch 45/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8564 - accuracy: 0.5778 - val_loss: 0.8348 - val_accuracy: 0.5836
# Epoch 46/50
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8622 - accuracy: 0.5802 - val_loss: 0.8381 - val_accuracy: 0.5975
# Epoch 47/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8506 - accuracy: 0.5879 - val_loss: 0.8419 - val_accuracy: 0.5960
# Epoch 48/50
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8616 - accuracy: 0.5689 - val_loss: 0.8398 - val_accuracy: 0.5867
# Epoch 49/50
# 81/81 [==============================] - 0s 5ms/step - loss: 0.8593 - accuracy: 0.5732 - val_loss: 0.8467 - val_accuracy: 0.5820
# Epoch 50/50
# 81/81 [==============================] - 0s 6ms/step - loss: 0.8557 - accuracy: 0.5813 - val_loss: 0.8402 - val_accuracy: 0.5913

# %% [markdown]
# ### Evaluating the model on the training and testing set

# %%
pcpscore = pcp_ann_model.evaluate(X_train, y_train, verbose=0)
print("Training Accuracy: {0:.2%}".format(pcpscore[1]))

pcpscore = pcp_ann_model.evaluate(X_test, y_test, verbose=0)
print("Testing Accuracy: {0:.2%}".format(pcpscore[1]))
# Out:
# Training Accuracy: 59.76%
# Testing Accuracy: 59.13%

# %% [markdown]
# ### Plot Epochs for Accracy and Loss

# %%
plt.plot(pcp_his.history['accuracy'])
plt.plot(pcp_his.history['val_accuracy'])
plt.title('PCP ANN Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(pcp_his.history['loss'])
plt.plot(pcp_his.history['val_loss'])
plt.title('PCP ANN Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## LCP Feature

# %%
df_lcpp = pd.read_csv('../../../Data/Features/LCP_data.csv',index_col=0)

# %%
df_lcpp.head()
# Out:
#     LCP1        LCP2        LCP3         LCP4         LCP5         LCP6  \
# 12   1.0   -4.620619   11.216498   -18.965210    24.804852   -26.135841
# 27   1.0   -4.243772    9.878223   -16.549742    21.832207   -23.426395
# 29   1.0   -4.550903   10.997309   -18.775156    24.923088   -26.633648
# 30   1.0   50.537933 -286.185970   745.173340 -1258.394200  1555.833300
# 31   1.0  125.109380 -540.967000  1161.417100 -1682.114900  1787.451500
#
#            LCP7         LCP8        LCP9       LCP10      LCP11 Label
# 12    22.393353   -15.348988    8.033380   -2.891480   0.543560   ang
# 27    20.516266   -14.562426    8.120422   -3.267545   0.721418   ang
# 29    23.093740   -16.064710    8.651243   -3.271798   0.654612   ang
# 30 -1455.320100  1020.872900 -502.843230  140.464550 -10.920460   sad
# 31 -1398.142600   757.090600 -213.570710  -31.442951  34.692960   sad

# %%
df_lcpp.shape
# Out:
# (3228, 12)

# %% [markdown]
# ### Extract features and Labels

# %%
lcpf = df_lcpp.drop(['Label'], axis=1).values
lcp_lab = df_lcpp['Label'].values
lcpcount= len(lcp_lab)

# %% [markdown]
# ### Convert features and corresponding classification labels into numpy arrays

# %%
X_lcp = np.array(lcpf.tolist())
y_lcp = np.array(lcp_lab.tolist())

# %% [markdown]
# ### Encode the classification labels

# %%
label_encoder = LabelEncoder()
encoded_labels_lcp = label_encoder.fit_transform(y_lcp)
encoded_labels_lcp = to_categorical(encoded_labels_lcp)

# %% [markdown]
# ### Split data inot training and testing set

# %%
X_train, X_test, y_train, y_test = train_test_split(X_lcp, encoded_labels_lcp, test_size=0.2, random_state=21)

# %% [markdown]
# ### Build the model

# %%
lcp_ann_model = Sequential()
lcp_ann_model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
lcp_ann_model.add(Dense(64, activation='relu'))
lcp_ann_model.add(Dense(len(label_encoder.classes_), activation='softmax'))

# %% [markdown]
# ### Model Summary

# %%
lcp_ann_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 128)               1536
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 9,987
# Trainable params: 9,987
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile and Fit the model

# %%
# Compile the model
lcp_ann_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
lcp_his = lcp_ann_model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# 81/81 [==============================] - 2s 8ms/step - loss: 609.5027 - accuracy: 0.3544 - val_loss: 58.7223 - val_accuracy: 0.3498
# Epoch 2/50
# 81/81 [==============================] - 0s 4ms/step - loss: 131.1596 - accuracy: 0.3420 - val_loss: 43.3093 - val_accuracy: 0.3019
# Epoch 3/50
# 81/81 [==============================] - 0s 4ms/step - loss: 133.8521 - accuracy: 0.3400 - val_loss: 32.0641 - val_accuracy: 0.3220
# Epoch 4/50
# 81/81 [==============================] - 0s 4ms/step - loss: 1171.1111 - accuracy: 0.3548 - val_loss: 258.2027 - val_accuracy: 0.3173
# Epoch 5/50
# 81/81 [==============================] - 0s 4ms/step - loss: 1192.2340 - accuracy: 0.3493 - val_loss: 136.0784 - val_accuracy: 0.3142
# Epoch 6/50
# 81/81 [==============================] - 0s 3ms/step - loss: 903.1036 - accuracy: 0.3613 - val_loss: 104.8987 - val_accuracy: 0.3189
# Epoch 7/50
# 81/81 [==============================] - 0s 5ms/step - loss: 1068.7292 - accuracy: 0.3373 - val_loss: 242.3373 - val_accuracy: 0.3359
# Epoch 8/50
# 81/81 [==============================] - 0s 3ms/step - loss: 2163.1482 - accuracy: 0.3765 - val_loss: 351.4988 - val_accuracy: 0.3003
# Epoch 9/50
# 81/81 [==============================] - 0s 3ms/step - loss: 1856.3597 - accuracy: 0.3582 - val_loss: 233.6947 - val_accuracy: 0.3529
# Epoch 10/50
# 81/81 [==============================] - 0s 3ms/step - loss: 1506.0358 - accuracy: 0.3439 - val_loss: 184.8805 - val_accuracy: 0.3731
# Epoch 11/50
# 81/81 [==============================] - 0s 4ms/step - loss: 676.4776 - accuracy: 0.3280 - val_loss: 56.9263 - val_accuracy: 0.3111
# Epoch 12/50
# 81/81 [==============================] - 0s 4ms/step - loss: 283.3287 - accuracy: 0.3238 - val_loss: 63.6742 - val_accuracy: 0.3885
# Epoch 13/50
# 81/81 [==============================] - 0s 4ms/step - loss: 5586.8716 - accuracy: 0.3594 - val_loss: 676.6997 - val_accuracy: 0.3684
# Epoch 14/50
lcpscore = lcp_ann_model.evaluate(X_train, y_train, verbose=0)
print("Training Accuracy: {0:.2%}".format(lcpscore[1]))

lcpscore = lcp_ann_model.evaluate(X_test, y_test, verbose=0)
print("Testing Accuracy: {0:.2%}".format(lcpscore[1]))
# Out:
# Training Accuracy: 37.57%
# Testing Accuracy: 40.25%

# %% [markdown]
# ### Plot Epochs for Accracy and Loss

# %%
plt.plot(lcp_his.history['accuracy'])
plt.plot(lcp_his.history['val_accuracy'])
plt.title('LCP ANN Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(lcp_his.history['loss'])
plt.plot(lcp_his.history['val_loss'])
plt.title('LCP ANN Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Artificial neural network (ANN) model that has been trained and tested on different sets of features: MFCC (Mel-Frequency Cepstral Coefficients), PCP (Pitch Class Profiles), and LCP (Log-Chroma features). The training and testing accuracies for each feature set are provided.
#
# 1. **MFCC Feature:**
#    - **Training Accuracy:** 76.87%
#    - **Testing Accuracy:** 71.38%
#
#    High training accuracy suggests that the model has learned well from the MFCC features during the training phase. However, there is a slight drop in testing accuracy, indicating a potential issue with overfitting. This could mean that the model may not generalize as well to new, unseen data.
#
# 2. **PCP Feature:**
#    - **Training Accuracy:** 59.76%
#    - **Testing Accuracy:** 59.13%
#
#    The training and testing accuracies are quite close, suggesting that the model is generalizing reasonably well to new data. However, the overall accuracy is not as high as with the MFCC features, indicating that PCP features might not be as effective for this particular task.
#
# 3. **LCP Feature:**
#    - **Training Accuracy:** 37.57%
#    - **Testing Accuracy:** 40.25%
#
#    Both the training and testing accuracies are relatively low, indicating that the model struggles to learn from the LCP features. This could be due to the features themselves not containing sufficient discriminative information for the task, or it may require further optimization of the model architecture or hyperparameters.
#
# **Conclusion:**
# - The MFCC features seem to be the most effective among the three, with the highest training and testing accuracies. However, there may be a slight overfitting issue that could be addressed by regularization techniques or increasing the size and diversity of the training dataset.
#
# - The PCP features show decent generalization but still fall short compared to MFCC. It might be worth exploring other feature combinations or data preprocessing techniques to improve the model's performance.
#
# - The LCP features exhibit the lowest accuracies, suggesting that these features alone may not be sufficient for the task. Consideration should be given to feature engineering or selecting a different set of features that capture more relevant information for the classification problem.
#
# In summary, further analysis, experimentation, and potentially refining the model or feature extraction process could lead to improved performance. It's crucial to understand the characteristics of each feature set and iteratively refine the model to achieve better results.

# %% [markdown]
# ### Why less accuracy seen?

# %% [markdown]
# Feature Relevance:
# The choice of features plays a crucial role. MFCC features are widely used in audio processing due to their ability to capture important characteristics of speech signals.
#
# Feature Engineering:
# The extraction process for PCP and LCP features might not be optimized or might not capture the relevant information in the data as effectively as MFCC.
#
# Model Complexity: The ANN architecture may not be well-suited for handling the specific characteristics represented by PCP and LCP features.
#
# Data Characteristics: The distribution and nature of the data may favor certain types of features, and the less accurate features may not align well with the underlying patterns in the dataset.
#
#
# To improve the accuracy for PCP and LCP features, you might consider exploring alternative feature representations, adjusting the model architecture, or further refining the feature extraction process. Experimenting with hyperparameter tuning and cross-validation could also provide insights into enhancing model performance.
